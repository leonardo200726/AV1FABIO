# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:Leonardo Heyer
#
# **Turma: 2A TI
#
# **Tema Escolhido:Notas de uma escola e medias

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Aluno_Leonardo:
    def __init__(self, nome, notas):
        self.nome = nome
        self.notas = notas
        
    def calcular_media_Leonardo(self):
        media = sum(self.notas) / len(self.notas)
        return round(media, 2)
    
    def exibir_dados_Leonardo(self):
        media = self.calcular_media_Leonardo()
        return f"Aluno: {self.nome}, Notas: {self.notas}, Média: {media}"

aluno1_Leonardo = Aluno_Leonardo("Carlos", [7.5, 8.0, 9.0])
aluno2_Leonardo = Aluno_Leonardo("Maria", [6.0, 7.0, 8.5])

print(aluno1_Leonardo.exibir_dados_Leonardo())
print(aluno2_Leonardo.exibir_dados_Leonardo())

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Aluno_Leonardo:
    def __init__(self, nome, notas):
        self.nome = nome
        self.notas = notas
        
    def calcular_media_Leonardo(self):
        media = sum(self.notas) / len(self.notas)
        return round(media, 2)
    
    def exibir_dados_Leonardo(self):
        media = self.calcular_media_Leonardo()
        return f"Aluno: {self.nome}, Notas: {self.notas}, Média: {media}"
    
    def adicionar_nota_Leonardo(self, nova_nota):
        self.notas.append(nova_nota)
        
    def remover_nota_Leonardo(self, nota):
        if nota in self.notas:
            self.notas.remove(nota)

class Aluno_Graduacao_Leonardo(Aluno_Leonardo):
    def __init__(self, nome, notas, curso):
        super().__init__(nome, notas)
        self.curso = curso
        
    def exibir_dados_Graduacao_Leonardo(self):
        dados = super().exibir_dados_Leonardo()
        return f"{dados}, Curso: {self.curso}"
    
    def alterar_curso_Leonardo(self, novo_curso):
        self.curso = novo_curso

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Aluno_Leonardo:
    def __init__(self, nome, notas):
        self.__nome = nome  # Atributo privado
        self.__notas = notas
        
    def calcular_media_Leonardo(self):
        media = sum(self.__notas) / len(self.__notas)
        return round(media, 2)
    
    def exibir_dados_Leonardo(self):
        media = self.calcular_media_Leonardo()
        return f"Aluno: {self.__nome}, Notas: {self.__notas}, Média: {media}"
    
    def adicionar_nota_Leonardo(self, nova_nota):
        self.__notas.append(nova_nota)
        
    def remover_nota_Leonardo(self, nota):
        if nota in self.__notas:
            self.__notas.remove(nota)
    
    # Métodos get e set para o atributo privado __nome
    def get_nome_Leonardo(self):
        return self.__nome
    
    def set_nome_Leonardo(self, novo_nome):
        self.__nome = novo_nome
    
    # Método com lógica interna: verifica se o aluno passou ou reprovou
    def verificar_status_Leonardo(self):
        media = self.calcular_media_Leonardo()
        if media >= 7.0:
            return f"{self.__nome} está aprovado!"
        else:
            return f"{self.__nome} está reprovado!"
    

class Aluno_Graduacao_Leonardo(Aluno_Leonardo):
    def __init__(self, nome, notas, curso):
        super().__init__(nome, notas)
        self.curso = curso
        
    def exibir_dados_Graduacao_Leonardo(self):
        dados = super().exibir_dados_Leonardo()
        return f"{dados}, Curso: {self.curso}"
    
    def alterar_curso_Leonardo(self, novo_curso):
        self.curso = novo_curso

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3
import json

class Aluno_Leonardo:
    def __init__(self, nome, notas):
        self.__nome_Leonardo = nome
        self.__notas_Leonardo = notas
        
    def calcular_media_Leonardo(self):
        media = sum(self.__notas_Leonardo) / len(self.__notas_Leonardo)
        return round(media, 2)
    
    def exibir_dados_Leonardo(self):
        media = self.calcular_media_Leonardo()
        return f"Aluno: {self.__nome_Leonardo}, Notas: {self.__notas_Leonardo}, Média: {media}"
    
    def adicionar_nota_Leonardo(self, nova_nota):
        self.__notas_Leonardo.append(nova_nota)
        
    def remover_nota_Leonardo(self, nota):
        if nota in self.__notas_Leonardo:
            self.__notas_Leonardo.remove(nota)
    
    def get_nome_Leonardo(self):
        return self.__nome_Leonardo
    
    def set_nome_Leonardo(self, novo_nome):
        self.__nome_Leonardo = novo_nome
    
    def verificar_status_Leonardo(self):
        media = self.calcular_media_Leonardo()
        if media >= 7.0:
            return f"{self.__nome_Leonardo} está aprovado!"
        else:
            return f"{self.__nome_Leonardo} está reprovado!"
    
    def salvar_no_banco_Leonardo(self):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('''CREATE TABLE IF NOT EXISTS alunos_Leonardo (
                            id INTEGER PRIMARY KEY,
                            nome TEXT,
                            notas TEXT,
                            curso TEXT)''')
        
        notas_json = json.dumps(self.__notas_Leonardo)
        cursor.execute('INSERT INTO alunos_Leonardo (nome, notas) VALUES (?, ?)', 
                       (self.__nome_Leonardo, notas_json))
        
        connection.commit()
        connection.close()

class Aluno_Graduacao_Leonardo(Aluno_Leonardo):
    def __init__(self, nome, notas, curso):
        super().__init__(nome, notas)
        self.curso_Leonardo = curso
        
    def exibir_dados_Leonardo(self):
        dados = super().exibir_dados_Leonardo()
        return f"{dados}, Curso: {self.curso_Leonardo}"
    
    def alterar_curso_Leonardo(self, novo_curso):
        self.curso_Leonardo = novo_curso
    
    def salvar_no_banco_Leonardo(self):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('''CREATE TABLE IF NOT EXISTS alunos_Leonardo (
                            id INTEGER PRIMARY KEY,
                            nome TEXT,
                            notas TEXT,
                            curso TEXT)''')
        
        notas_json = json.dumps(self.__notas_Leonardo)
        cursor.execute('INSERT INTO alunos_Leonardo (nome, notas, curso) VALUES (?, ?, ?)', 
                       (self.get_nome_Leonardo(), notas_json, self.curso_Leonardo))
        
        connection.commit()
        connection.close()

    def consultar_aluno_Leonardo(self, nome):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('SELECT * FROM alunos_Leonardo WHERE nome = ?', (nome,))
        aluno = cursor.fetchone()
        connection.close()
        return aluno

    def excluir_aluno_Leonardo(self, nome):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('DELETE FROM alunos_Leonardo WHERE nome = ?', (nome,))
        connection.commit()
        connection.close()

# Testando as funcionalidades
aluno1_Leonardo = Aluno_Leonardo("Carlos", [7.5, 8.0, 9.0])
aluno1_Leonardo.salvar_no_banco_Leonardo()

aluno2_Graduacao_Leonardo = Aluno_Graduacao_Leonardo("Maria", [6.0, 7.0, 8.5], "Engenharia")
aluno2_Graduacao_Leonardo.salvar_no_banco_Leonardo()

# Consultar um aluno no banco
print(aluno2_Graduacao_Leonardo.consultar_aluno_Leonardo("Maria"))

# Excluir um aluno do banco
aluno2_Graduacao_Leonardo.excluir_aluno_Leonardo("Maria")

# Consultar após exclusão
print(aluno2_Graduacao_Leonardo.consultar_aluno_Leonardo("Maria"))

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3
import json

class Aluno_Leonardo:
    def __init__(self, nome, notas):
        self.__nome_Leonardo = nome
        self.__notas_Leonardo = notas
        
    def calcular_media_Leonardo(self):
        media = sum(self.__notas_Leonardo) / len(self.__notas_Leonardo)
        return round(media, 2)
    
    def exibir_dados_Leonardo(self):
        media = self.calcular_media_Leonardo()
        return f"Aluno: {self.__nome_Leonardo}, Notas: {self.__notas_Leonardo}, Média: {media}"
    
    def adicionar_nota_Leonardo(self, nova_nota):
        self.__notas_Leonardo.append(nova_nota)
        
    def remover_nota_Leonardo(self, nota):
        if nota in self.__notas_Leonardo:
            self.__notas_Leonardo.remove(nota)
    
    def get_nome_Leonardo(self):
        return self.__nome_Leonardo
    
    def set_nome_Leonardo(self, novo_nome):
        self.__nome_Leonardo = novo_nome
    
    def verificar_status_Leonardo(self):
        media = self.calcular_media_Leonardo()
        if media >= 7.0:
            return f"{self.__nome_Leonardo} está aprovado!"
        else:
            return f"{self.__nome_Leonardo} está reprovado!"
    
    def salvar_no_banco_Leonardo(self):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('''CREATE TABLE IF NOT EXISTS alunos_Leonardo (
                            id INTEGER PRIMARY KEY,
                            nome TEXT,
                            notas TEXT,
                            curso TEXT)''')
        
        notas_json = json.dumps(self.__notas_Leonardo)
        cursor.execute('INSERT INTO alunos_Leonardo (nome, notas) VALUES (?, ?)', 
                       (self.__nome_Leonardo, notas_json))
        
        connection.commit()
        connection.close()

class Aluno_Graduacao_Leonardo(Aluno_Leonardo):
    def __init__(self, nome, notas, curso):
        super().__init__(nome, notas)
        self.curso_Leonardo = curso
        
    def exibir_dados_Leonardo(self):
        dados = super().exibir_dados_Leonardo()
        return f"{dados}, Curso: {self.curso_Leonardo}"
    
    def alterar_curso_Leonardo(self, novo_curso):
        self.curso_Leonardo = novo_curso
    
    def salvar_no_banco_Leonardo(self):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('''CREATE TABLE IF NOT EXISTS alunos_Leonardo (
                            id INTEGER PRIMARY KEY,
                            nome TEXT,
                            notas TEXT,
                            curso TEXT)''')
        
        notas_json = json.dumps(self.__notas_Leonardo)
        cursor.execute('INSERT INTO alunos_Leonardo (nome, notas, curso) VALUES (?, ?, ?)', 
                       (self.get_nome_Leonardo(), notas_json, self.curso_Leonardo))
        
        connection.commit()
        connection.close()

    def consultar_aluno_Leonardo(self, nome):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('SELECT * FROM alunos_Leonardo WHERE nome = ?', (nome,))
        aluno = cursor.fetchone()
        connection.close()
        return aluno

    def excluir_aluno_Leonardo(self, nome):
        connection = sqlite3.connect('alunos_Leonardo.db')
        cursor = connection.cursor()
        cursor.execute('DELETE FROM alunos_Leonardo WHERE nome = ?', (nome,))
        connection.commit()
        connection.close()

aluno1_Leonardo = Aluno_Leonardo("Carlos", [7.5, 8.0, 9.0])
aluno1_Leonardo.salvar_no_banco_Leonardo()

aluno2_Graduacao_Leonardo = Aluno_Graduacao_Leonardo("Maria", [6.0, 7.0, 8.5], "Engenharia")
aluno2_Graduacao_Leonardo.salvar_no_banco_Leonardo()

print(aluno2_Graduacao_Leonardo.consultar_aluno_Leonardo("Maria"))

aluno2_Graduacao_Leonardo.excluir_aluno_Leonardo("Maria")

print(aluno2_Graduacao_Leonardo.consultar_aluno_Leonardo("Maria"))

aluno1_Leonardo.set_nome_Leonardo("Carlos Henrique")
print(aluno1_Leonardo.exibir_dados_Leonardo())
